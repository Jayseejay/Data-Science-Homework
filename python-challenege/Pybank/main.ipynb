# %%
from csv import reader
import os
import csv

# %%
total_player = 0
opened_file = open('Resources/budget_data.csv')
read_file = reader(opened_file)
apps_data = list(read_file)

# %%
print(apps_data)
# Out:
# [['Date', 'Profit/Losses'], ['Jan-2010', '867884'], ['Feb-2010', '984655'], ['Mar-2010', '322013'], ['Apr-2010', '-69417'], ['May-2010', '310503'], ['Jun-2010', '522857'], ['Jul-2010', '1033096'], ['Aug-2010', '604885'], ['Sep-2010', '-216386'], ['Oct-2010', '477532'], ['Nov-2010', '893810'], ['Dec-2010', '-80353'], ['Jan-2011', '779806'], ['Feb-2011', '-335203'], ['Mar-2011', '697845'], ['Apr-2011', '793163'], ['May-2011', '485070'], ['Jun-2011', '584122'], ['Jul-2011', '62729'], ['Aug-2011', '668179'], ['Sep-2011', '899906'], ['Oct-2011', '834719'], ['Nov-2011', '132003'], ['Dec-2011', '309978'], ['Jan-2012', '-755566'], ['Feb-2012', '1170593'], ['Mar-2012', '252788'], ['Apr-2012', '1151518'], ['May-2012', '817256'], ['Jun-2012', '570757'], ['Jul-2012', '506702'], ['Aug-2012', '-1022534'], ['Sep-2012', '475062'], ['Oct-2012', '779976'], ['Nov-2012', '144175'], ['Dec-2012', '542494'], ['Jan-2013', '359333'], ['Feb-2013', '321469'], ['Mar-2013', '67780'], ['Apr-2013', '471435'], ['Ma
# ...

# %%
for players in apps_data:
    total_players = players + apps_data[1]
    print(total_players)
# Out:
# ['Date', 'Profit/Losses', 'Jan-2010', '867884']
# ['Jan-2010', '867884', 'Jan-2010', '867884']
# ['Feb-2010', '984655', 'Jan-2010', '867884']
# ['Mar-2010', '322013', 'Jan-2010', '867884']
# ['Apr-2010', '-69417', 'Jan-2010', '867884']
# ['May-2010', '310503', 'Jan-2010', '867884']
# ['Jun-2010', '522857', 'Jan-2010', '867884']
# ['Jul-2010', '1033096', 'Jan-2010', '867884']
# ['Aug-2010', '604885', 'Jan-2010', '867884']
# ['Sep-2010', '-216386', 'Jan-2010', '867884']
# ['Oct-2010', '477532', 'Jan-2010', '867884']
# ['Nov-2010', '893810', 'Jan-2010', '867884']
# ['Dec-2010', '-80353', 'Jan-2010', '867884']
# ['Jan-2011', '779806', 'Jan-2010', '867884']
# ['Feb-2011', '-335203', 'Jan-2010', '867884']
# ['Mar-2011', '697845', 'Jan-2010', '867884']
# ['Apr-2011', '793163', 'Jan-2010', '867884']
# ['May-2011', '485070', 'Jan-2010', '867884']
# ['Jun-2011', '584122', 'Jan-2010', '867884']
# ['Jul-2011', '62729', 'Jan-2010', '867884']
# ['Aug-2011', '668179', 'Jan-2010', '867884']
# ...
